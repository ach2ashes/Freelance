# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

option = Options()
service = Service(executable_path="C:\\Users\\PC2\\Downloads\\msedgedriver.exe")
# Uncomment the next line to run in headless mode
# option.add_argument("--headless")
option.add_argument("user-data-dir=C:\\Users\\PC2\\AppData\\Local\\Microsoft\\Edge\\User Data")  # Path to Edge user data directory
#option.add_argument("--no-sandbox")
#option.add_argument("--disable-dev-shm-usage")

driver = webdriver.Edge(service=service, options=option)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[6], line 13
#       9 option.add_argument("user-data-dir=C:\\Users\\PC2\\AppData\\Local\\Microsoft\\Edge\\User Data")  # Path to Edge user data directory
#      10 #option.add_argument("--no-sandbox")
#      11 #option.add_argument("--disable-dev-shm-usage")
# ---> 13 driver = webdriver.Edge(service=service, options=option)
#
# File c:\Users\PC2\anaconda3\Lib\site-packages\selenium\webdriver\edge\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     DesiredCapabilities.EDGE["browserName"],
#      47     "ms",
#      48     options,
#      49     service,
#      50     keep_alive,
#      51 )
#
# ...

# %%
import time                                                    #importing the time module       
driver.get("https://tinder.com/app/explore/cl_tfihp")
driver.implicitly_wait(50)
while True :
    try: 
        try :
            l = driver.find_element(By.XPATH,"//button[@class='button Lts($ls-s) Z(0) CenterAlign Mx(a) Cur(p) Tt(u) Bdrs(50%) P(0) Fw($semibold) focus-button-style Bxsh($bxsh-btn) Expand Trstf(e) Trsdu($normal) Wc($transform) Pe(a) Scale(1.1):h Scale(.9):a Bgi($g-ds-background-like):a']")
            l.click()
            time.sleep(1)
        except :    
            signup  = driver.find_element(By.XPATH , "//div[contains(text(),'No Thanks')]")
            signup.click()
    except:
        driver.refresh()
        time.sleep(600)
    #time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 7
#       6 try :
# ----> 7     l = driver.find_element(By.XPATH,"//button[@class='button Lts($ls-s) Z(0) CenterAlign Mx(a) Cur(p) Tt(u) Bdrs(50%) P(0) Fw($semibold) focus-button-style Bxsh($bxsh-btn) Expand Trstf(e) Trsdu($normal) Wc($transform) Pe(a) Scale(1.1):h Scale(.9):a Bgi($g-ds-background-like):a']")
#       8     l.click()
#
# File c:\Users\PC2\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\PC2\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343         params["sessionId"] = self.session_id
# ...
