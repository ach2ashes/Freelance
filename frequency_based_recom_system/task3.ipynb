# %%
from typing import List, Tuple
from collections import defaultdict


class Itemset:
    def __init__(self, items: List[str], support: int):
        self.items = items
        self.support = support


def prefixspan(db: List[List[str]], minsup: int) -> List[Itemset]:
    freq_itemsets = []
    support_counts = defaultdict(int)
    for transaction in db:
        for item in set(transaction):
            support_counts[item] += 1
    freq_items = set(item for item, count in support_counts.items() if count >= minsup)
    for item in freq_items:
        freq_itemsets.append(Itemset([item], support_counts[item]))
    while freq_items:
        new_freq_items = set()
        new_db = []
        for transaction in db:
            if not set(freq_items).intersection(set(transaction)):
                continue
            new_transaction = []
            for item in transaction:
                if item in freq_items:
                    new_transaction.append(item)
            new_db.append(new_transaction)
            for i, item in enumerate(new_transaction):
                if i == 0:
                    prefix = []
                else:
                    prefix = new_transaction[:i]
                suffix = new_transaction[i+1:]
                new_itemset = prefix + suffix
                if new_itemset:
                    support_counts[str(new_itemset)] += 1
                    if support_counts[str(new_itemset)] == minsup:
                        new_freq_items.add(str(new_itemset))
        freq_items = new_freq_items
        for itemset in freq_items:
            freq_itemsets.append(Itemset(eval(itemset), support_counts[itemset]))
    return freq_itemsets
# Load the dataset from a CSV file
import pandas as pd
df = pd.read_csv('groceries.csv')
transactions = df.groupby(['Member_number', 'Date'])['itemDescription'].apply(list).tolist()

# Generate the frequent itemsets with a minimum support of 100
freq_itemsets = prefixspan(transactions, 100)



##Code adapted from
# Out:
# ['frozen vegetables'] 301
# ['brown bread'] 411
# ['UHT-milk'] 209
# ['napkins'] 248
# ['pip fruit'] 507
# ['canned beer'] 480
# ['processed cheese'] 114
# ['root vegetables'] 717
# ['soda'] 1030
# ['yogurt'] 894
# ['dessert'] 244
# ['domestic eggs'] 394
# ['chocolate'] 252
# ['tropical fruit'] 673
# ['rolls/buns'] 1161
# ['shopping bags'] 491
# ['herbs'] 112
# ['long life bakery product'] 177
# ['beverages'] 172
# ['ham'] 187
# ['salty snack'] 185
# ['pork'] 380
# ['berries'] 231
# ['frozen meals'] 185
# ['soft cheese'] 104
# ['red/blush wine'] 115
# ['hard cheese'] 148
# ['specialty bar'] 149
# ['newspapers'] 405
# ['citrus fruit'] 553
# ['cream cheese '] 254
# ['cat food'] 124
# ['oil'] 153
# ['sausage'] 629
# ['chewing gum'] 121
# ['ice cream'] 157
# ['coffee'] 356
# ['other vegetables'] 1290
# ['candy'] 142
# ['sugar'] 184
# ['sliced cheese'] 143
# ['frankfurter'] 401
# ['onions'] 218
# ['margarine'] 348
# ['white bread'] 247
# ['whipped/sour cream'] 465
# ['meat'] 184
# ['butter'] 377
# ['whole milk'] 1641
# ['butter milk'] 176
# ['bottled water'] 655
# ['hygiene articles'] 147
# ['waffles'] 191
# ['fruit/vegetable juice'] 361
# ['hamburger meat'] 232
# ['bottled beer'] 488
# ['pastry'] 553
# ['curd'] 362
# ['white wine'] 120
# ['grapes'] 146
# ['chicken'] 291
# ['misc. beverages'] 172
# ['specialty chocolate'] 166
# ['beef'] 367
# ['dessert'] 126
# ['shopping bags'] 234
# ['fruit/vegetable juice'] 162
# ['white bread'] 119
# ['pork'] 181
# ['cream cheese '] 116
# ['tropical fruit'] 292
# ['frankfurter'] 187
# ['bottled water'] 303
# ['yogurt'] 416
# ['brown bread'] 188
# ['onions'] 104
# ['domestic eggs'] 182
# ['canned beer'] 228
# ['sausage'] 261
# ['rolls/buns'] 539
# ['margarine'] 180
# ['citrus fruit'] 281
# ['butter'] 200
# ['root vegetables'] 357
# ['pastry'] 251
# ['whipped/sour cream'] 236
# ['beef'] 169
# ['coffee'] 174
# ['chocolate'] 127
# ['newspapers'] 180
# ['whole milk'] 781
# ['chicken'] 125
# ['berries'] 108
# ['soda'] 488
# ['other vegetables'] 592
# ['curd'] 169
# ['bottled beer'] 220
# ['pip fruit'] 239
# ['napkins'] 117
# ['frozen vegetables'] 130

# %%
# Define a function to generate recommendations based on the frequent itemsets
def generate_recommendations(purchased_items, freq_itemsets, num_recommendations=5):
    # Create a dictionary to store the support counts for each item in the frequent itemsets
    support_counts = defaultdict(int)
    # Increment the support counts for each item that appears in the frequent itemsets
    for itemset in freq_itemsets:
        for item in itemset.items:
            if item not in purchased_items:
                support_counts[item] += itemset.support
    # Sort the items by their support counts in descending order
    sorted_items = sorted(support_counts.items(), key=lambda x: x[1], reverse=True)
    # Return the top N items as recommendations
    return [item for item, count in sorted_items[:num_recommendations]]

# Test the recommendation system
purchased_items = ['candy']
recommendations = generate_recommendations(purchased_items, freq_itemsets)
print(f"Recommendations for {purchased_items}: {recommendations}")
# Out:
# [<__main__.Itemset object at 0x000001F2AAB87250>, <__main__.Itemset object at 0x000001F2AAB872B0>, <__main__.Itemset object at 0x000001F2BBD9E580>, <__main__.Itemset object at 0x000001F2BBD9E5E0>, <__main__.Itemset object at 0x000001F2BBD9E250>, <__main__.Itemset object at 0x000001F2BBD9E400>, <__main__.Itemset object at 0x000001F2BBD9E460>, <__main__.Itemset object at 0x000001F2BBD9E2B0>, <__main__.Itemset object at 0x000001F2BBD9E1F0>, <__main__.Itemset object at 0x000001F2BBD9E670>, <__main__.Itemset object at 0x000001F2BC1FC550>, <__main__.Itemset object at 0x000001F2BC1FC5E0>, <__main__.Itemset object at 0x000001F2BC1FC760>, <__main__.Itemset object at 0x000001F2BC1FC730>, <__main__.Itemset object at 0x000001F2BC1FC4F0>, <__main__.Itemset object at 0x000001F2BC1FC7C0>, <__main__.Itemset object at 0x000001F2BC1FC820>, <__main__.Itemset object at 0x000001F2BC1FC880>, <__main__.Itemset object at 0x000001F2BC1FC8E0>, <__main__.Itemset object at 0x000001F2BC1FC940>, <__main__.Itemset object at 0x000001F2BC1FC9A0>, <__main__.Itemset object at 0x000001F2BC1FCA00>, <__main__.Itemset object at 0x000001F2BC1FCA60>, <__main__.Itemset object at 0x000001F2BC1FCAC0>, <__main__.Itemset object at 0x000001F2BC1FCB20>, <__main__.Itemset object at 0x000001F2BC1FCB80>, <__main__.Itemset object at 0x000001F2BC1FCBE0>, <__main__.Itemset object at 0x000001F2BC1FCC40>, <__main__.Itemset object at 0x000001F2BC1FCCA0>, <__main__.Itemset object at 0x000001F2BC1FCD00>, <__main__.Itemset object at 0x000001F2BC1FCD60>, <__main__.Itemset object at 0x000001F2BC1FCDC0>, <__main__.Itemset object at 0x000001F2BC1FCE20>, <__main__.Itemset object at 0x000001F2BC1FCE80>, <__main__.Itemset object at 0x000001F2BC1FCEE0>, <__main__.Itemset object at 0x000001F2BC1FCF40>, <__main__.Itemset object at 0x000001F2BC1FCFA0>, <__main__.Itemset object at 0x000001F2BBDB7040>, <__main__.Itemset object at 0x000001F2BBDB70A0>, <__main__.Itemset object at 0x000001F2BBDB7100>, <__main__.Itemset object at 0x000001F2BBDB7160>, <__main__.Itemset object at 0x000001F2BBDB71C0>, <__main__.Itemset object at 0x000001F2BBDB7220>, <__main__.Itemset object at 0x000001F2BBDB7280>, <__main__.Itemset object at 0x000001F2BBDB72E0>, <__main__.Itemset object at 0x000001F2BBDB7340>, <__main__.Itemset object at 0x000001F2BBDB73A0>, <__main__.Itemset object at 0x000001F2BBDB7400>, <__main__.Itemset object at 0x000001F2BBDB7460>, <__main__.Itemset object at 0x000001F2BBDB74C0>, <__main__.Itemset object at 0x000001F2BBDB7520>, <__main__.Itemset object at 0x000001F2BBDB7580>, <__main__.Itemset object at 0x000001F2BBDB75E0>, <__main__.Itemset object at 0x000001F2BBDB7640>, <__main__.Itemset object at 0x000001F2BBDB76A0>, <__main__.Itemset object at 0x000001F2BBDB7700>, <__main__.Itemset object at 0x000001F2BBDB7760>, <__main__.Itemset object at 0x000001F2BBDB77C0>, <__main__.Itemset object at 0x000001F2BBDB7820>, <__main__.Itemset object at 0x000001F2BBDB7880>, <__main__.Itemset object at 0x000001F2BBDB78E0>, <__main__.Itemset object at 0x000001F2BBDB7940>, <__main__.Itemset object at 0x000001F2BBDB79A0>, <__main__.Itemset object at 0x000001F2BBDB7A00>, <__main__.Itemset object at 0x000001F2BBDB7B20>, <__main__.Itemset object at 0x000001F2BBDB7A90>, <__main__.Itemset object at 0x000001F2BBDB7B80>, <__main__.Itemset object at 0x000001F2BBDB7BE0>, <__main__.Itemset object at 0x000001F2BBDB7B50>, <__main__.Itemset object at 0x000001F2BBDB7C10>, <__main__.Itemset object at 0x000001F2BBDB7D00>, <__main__.Itemset object at 0x000001F2BBDB7D60>, <__main__.Itemset object at 0x000001F2BBDB7CD0>, <__main__.Itemset object at 0x000001F2BBDB7D90>, <__main__.Itemset object at 0x000001F2BBDB7DF0>, <__main__.Itemset object at 0x000001F2BBDB7E50>, <__main__.Itemset object at 0x000001F2BBDB7EB0>, <__main__.Itemset object at 0x000001F2BBDB7F10>, <__main__.Itemset object at 0x000001F2BBDB7FA0>, <__main__.Itemset object at 0x000001F2BC0870A0>, <__main__.Itemset object at 0x000001F2BC087070>, <__main__.Itemset object at 0x ...
# Recommendations for ['candy']: ['whole milk', 'other vegetables', 'rolls/buns', 'soda', 'yogurt']
